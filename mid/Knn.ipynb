# %%
# !unzip /content/animals.zip
# Out:
# Archive:  /content/animals.zip
#    creating: animals/
#    creating: animals/cats/
#   inflating: animals/cats/cats_00001.jpg
#   inflating: animals/cats/cats_00002.jpg
#   inflating: animals/cats/cats_00003.jpg
#   inflating: animals/cats/cats_00004.jpg
#   inflating: animals/cats/cats_00005.jpg
#   inflating: animals/cats/cats_00006.jpg
#   inflating: animals/cats/cats_00007.jpg
#   inflating: animals/cats/cats_00008.jpg
#   inflating: animals/cats/cats_00009.jpg
#   inflating: animals/cats/cats_00010.jpg
#   inflating: animals/cats/cats_00011.jpg
#   inflating: animals/cats/cats_00012.jpg
#   inflating: animals/cats/cats_00013.jpg
#   inflating: animals/cats/cats_00014.jpg
#   inflating: animals/cats/cats_00015.jpg
#   inflating: animals/cats/cats_00016.jpg
#   inflating: animals/cats/cats_00017.jpg
#   inflating: animals/cats/cats_00018.jpg
#   inflating: animals/cats/cats_00019.jpg
#   inflating: animals/cats/cats_00020.jpg
#   inflating: animals/cats/cats_00021.jpg
#   inflating: animals/cats/cats_00022.jpg
#   inflating: animals/cats/cats_00023.jpg
#   inflating: animals/cats/cats_00024.jpg
#   inflating: animals/cats/cats_00025.jpg
#   inflating: animals/cats/cats_00026.jpg
#   inflating: animals/cats/cats_00027.jpg
#   inflating: animals/cats/cats_00028.jpg
#   inflating: animals/cats/cats_00029.jpg
#   inflating: animals/cats/cats_00030.jpg
#   inflating: animals/cats/cats_00031.jpg
#   inflating: animals/cats/cats_00032.jpg
#   inflating: animals/cats/cats_00033.jpg
#   inflating: animals/cats/cats_00034.jpg
#   inflating: animals/cats/cats_00035.jpg
#   inflating: animals/cats/cats_00036.jpg
#   inflating: animals/cats/cats_00037.jpg
#   inflating: animals/cats/cats_00038.jpg
#   inflating: animals/cats/cats_00039.jpg
#   inflating: animals/cats/cats_00040.jpg
#   inflating: animals/cats/cats_00041.jpg
#   inflating: animals/cats/cats_00042.jpg
#   inflating: animals/cats/cats_00043.jpg
#   inflating: animals/cats/cats_00044.jpg
#   inflating: animals/cats/cats_00045.jpg
#   inflating: animals/cats/cats_00046.jpg
#   inflating: animals/cats/cats_00047.jpg
#   inflating: animals/cats/cats_00048.jpg
#   inflating: animals/cats/cats_00049.jpg
#   inflating: animals/cats/cats_00050.jpg
#   inflating: animals/cats/cats_00051.jpg
#   inflating: animals/cats/cats_00052.jpg
#   inflating: animals/cats/cats_00053.jpg
#   inflating: animals/cats/cats_00054.jpg
#   inflating: animals/cats/cats_00055.jpg
#   inflating: animals/cats/cats_00056.jpg
#   inflating: animals/cats/cats_00057.jpg
#   inflating: animals/cats/cats_00058.jpg
#   inflating: animals/cats/cats_00059.jpg
#   inflating: animals/cats/cats_00060.jpg
#   inflating: animals/cats/cats_00061.jpg
#   inflating: animals/cats/cats_00062.jpg
#   inflating: animals/cats/cats_00063.jpg
#   inflating: animals/cats/cats_00064.jpg
#   inflating: animals/cats/cats_00065.jpg
#   inflating: animals/cats/cats_00066.jpg
#   inflating: animals/cats/cats_00067.jpg
#   inflating: animals/cats/cats_00068.jpg
#   inflating: animals/cats/cats_00069.jpg
#   inflating: animals/cats/cats_00070.jpg
#   inflating: animals/cats/cats_00071.jpg
#   inflating: animals/cats/cats_00072.jpg
#   inflating: animals/cats/cats_00073.jpg
#   inflating: animals/cats/cats_00074.jpg
#   inflating: animals/cats/cats_00075.jpg
#   inflating: animals/cats/cats_00076.jpg
#   inflating: animals/cats/cats_00077.jpg
#   inflating: animals/cats/cats_00078.jpg
#   inflating: animals/cats/cats_00079.jpg
#   inflating: animals/cats/cats_00080.jpg
#   inflating: animals/cats/cats_00081.jpg
#   inflating: animals/cats/cats_00082.jpg
#   inflating: animals/cats/cats_00083.jpg
#   inflating: animals/cats/cats_00084.jpg
#   inflating: animals/cats/cats_00085.jpg
#   inflating: animals/cats/cats_00086.jpg
#   inflating: animals/cats/cats_00087.jpg
#   inflating: animals/cats/cats_00088.jpg
#   inflating: animals/cats/cats_00089.jpg
#   inflating: animals/cats/cats_00090.jpg
#   inflating: animals/cats/cats_00091.jpg
#   inflating: animals/cats/cats_00092.jpg
#   inflating: animals/cats/cats_00093.jpg
#   inflating: animals/cats/cats_00094.jpg
#   inflating: animals/cats/cats_00095.jpg
#   inflating: animals/cats/cats_00096.jpg
#   inflating: animals/cats/cats_00097.jpg
#   inflating: animals/cats/cats_00098.jpg
#   inflating: animals/cats/cats_00099.jpg
#   inflating: animals/cats/cats_00100.jpg
#    creating: animals/dogs/
#   inflating: animals/dogs/dogs_00001.jpg
#   inflating: animals/dogs/dogs_00002.jpg
#   inflating: animals/dogs/dogs_00003.jpg
#   inflating: animals/dogs/dogs_00004.jpg
#   inflating: animals/dogs/dogs_00005.jpg
#   inflating: animals/dogs/dogs_00006.jpg
#   inflating: animals/dogs/dogs_00007.jpg
#   inflating: animals/dogs/dogs_00008.jpg
#   inflating: animals/dogs/dogs_00009.jpg
#   inflating: animals/dogs/dogs_00010.jpg
#   inflating: animals/dogs/dogs_00011.jpg
#   inflating: animals/dogs/dogs_00012.jpg
#   inflating: animals/dogs/dogs_00013.jpg
#   inflating: animals/dogs/dogs_00014.jpg
#   inflating: animals/dogs/dogs_00015.jpg
#   inflating: animals/dogs/dogs_00016.jpg
#   inflating: animals/dogs/dogs_00017.jpg
#   inflating: animals/dogs/dogs_00018.jpg
#   inflating: animals/dogs/dogs_00019.jpg
#   inflating: animals/dogs/dogs_00020.jpg
#   inflating: animals/dogs/dogs_00021.jpg
#   inflating: animals/dogs/dogs_00022.jpg
#   inflating: animals/dogs/dogs_00023.jpg
#   inflating: animals/dogs/dogs_00024.jpg
#   inflating: animals/dogs/dogs_00025.jpg
#   inflating: animals/dogs/dogs_00026.jpg
#   inflating: animals/dogs/dogs_00027.jpg
#   inflating: animals/dogs/dogs_00028.jpg
#   inflating: animals/dogs/dogs_00029.jpg
#   inflating: animals/dogs/dogs_00030.jpg
#   inflating: animals/dogs/dogs_00031.jpg
#   inflating: animals/dogs/dogs_00032.jpg
#   inflating: animals/dogs/dogs_00033.jpg
#   inflating: animals/dogs/dogs_00034.jpg
#   inflating: animals/dogs/dogs_00035.jpg
#   inflating: animals/dogs/dogs_00036.jpg
#   inflating: animals/dogs/dogs_00037.jpg
#   inflating: animals/dogs/dogs_00038.jpg
#   inflating: animals/dogs/dogs_00039.jpg
#   inflating: animals/dogs/dogs_00040.jpg
#   inflating: animals/dogs/dogs_00041.jpg
#   inflating: animals/dogs/dogs_00042.jpg
#   inflating: animals/dogs/dogs_00043.jpg
#   inflating: animals/dogs/dogs_00044.jpg
#   inflating: animals/dogs/dogs_00045.jpg
#   inflating: animals/dogs/dogs_00046.jpg
#   inflating: animals/dogs/dogs_00047.jpg
#   inflating: animals/dogs/dogs_00048.jpg
#   inflating: animals/dogs/dogs_00049.jpg
#   inflating: animals/dogs/dogs_00050.jpg
#   inflating: animals/dogs/dogs_00051.jpg
#   inflating: animals/dogs/dogs_00052.jpg
#   inflating: animals/dogs/dogs_00053.jpg
#   inflating: animals/dogs/dogs_00054.jpg
#   inflating: animals/dogs/dogs_00055.jpg
#   inflating: animals/dogs/dogs_00056.jpg
#   inflating: animals/dogs/dogs_00057.jpg
#   inflating: animals/dogs/dogs_00058.jpg
#   inflating: animals/dogs/dogs_00059.jpg
#   inflating: animals/dogs/dogs_00060.jpg
#   inflating: animals/dogs/dogs_00061.jpg
#   inflating: animals/dogs/dogs_00062.jpg
#   inflating: animals/dogs/dogs_00063.jpg
#   inflating: animals/dogs/dogs_00064.jpg
#   inflating: animals/dogs/dogs_00065.jpg
#   inflating: animals/dogs/dogs_00066.jpg
#   inflating: animals/dogs/dogs_00067.jpg
#   inflating: animals/dogs/dogs_00068.jpg
#   inflating: animals/dogs/dogs_00069.jpg
#   inflating: animals/dogs/dogs_00070.jpg
#   inflating: animals/dogs/dogs_00071.jpg
#   inflating: animals/dogs/dogs_00072.jpg
#   inflating: animals/dogs/dogs_00073.jpg
#   inflating: animals/dogs/dogs_00074.jpg
#   inflating: animals/dogs/dogs_00075.jpg
#   inflating: animals/dogs/dogs_00076.jpg
#   inflating: animals/dogs/dogs_00077.jpg
#   inflating: animals/dogs/dogs_00078.jpg
#   inflating: animals/dogs/dogs_00079.jpg
#   inflating: animals/dogs/dogs_00080.jpg
#   inflating: animals/dogs/dogs_00081.jpg
#   inflating: animals/dogs/dogs_00082.jpg
#   inflating: animals/dogs/dogs_00083.jpg
#   inflating: animals/dogs/dogs_00084.jpg
#   inflating: animals/dogs/dogs_00085.jpg
#   inflating: animals/dogs/dogs_00086.jpg
#   inflating: animals/dogs/dogs_00087.jpg
#   inflating: animals/dogs/dogs_00088.jpg
#   inflating: animals/dogs/dogs_00089.jpg
#   inflating: animals/dogs/dogs_00090.jpg
#   inflating: animals/dogs/dogs_00091.jpg
#   inflating: animals/dogs/dogs_00092.jpg
#   inflating: animals/dogs/dogs_00093.jpg
#   inflating: animals/dogs/dogs_00094.jpg
#   inflating: animals/dogs/dogs_00095.jpg
#   inflating: animals/dogs/dogs_00096.jpg
#   inflating: animals/dogs/dogs_00097.jpg
#   inflating: animals/dogs/dogs_00098.jpg
#   inflating: animals/dogs/dogs_00099.jpg
#   inflating: animals/dogs/dogs_00100.jpg
#    creating: animals/panda/
#   inflating: animals/panda/panda_00001.jpg
#   inflating: animals/panda/panda_00002.jpg
#   inflating: animals/panda/panda_00003.jpg
#   inflating: animals/panda/panda_00004.jpg
#   inflating: animals/panda/panda_00005.jpg
#   inflating: animals/panda/panda_00006.jpg
#   inflating: animals/panda/panda_00007.jpg
#   inflating: animals/panda/panda_00008.jpg
#   inflating: animals/panda/panda_00009.jpg
#   inflating: animals/panda/panda_00010.jpg
#   inflating: animals/panda/panda_00011.jpg
#   inflating: animals/panda/panda_00012.jpg
#   inflating: animals/panda/panda_00013.jpg
#   inflating: animals/panda/panda_00014.jpg
#   inflating: animals/panda/panda_00015.jpg
#   inflating: animals/panda/panda_00016.jpg
#   inflating: animals/panda/panda_00017.jpg
#   inflating: animals/panda/panda_00018.jpg
#   inflating: animals/panda/panda_00019.jpg
#   inflating: animals/panda/panda_00020.jpg
#   inflating: animals/panda/panda_00021.jpg
#   inflating: animals/panda/panda_00022.jpg
#   inflating: animals/panda/panda_00023.jpg
#   inflating: animals/panda/panda_00024.jpg
#   inflating: animals/panda/panda_00025.jpg
#   inflating: animals/panda/panda_00026.jpg
#   inflating: animals/panda/panda_00027.jpg
#   inflating: animals/panda/panda_00028.jpg
#   inflating: animals/panda/panda_00029.jpg
#   inflating: animals/panda/panda_00030.jpg
#   inflating: animals/panda/panda_00031.jpg
#   inflating: animals/panda/panda_00032.jpg
#   inflating: animals/panda/panda_00033.jpg
#   inflating: animals/panda/panda_00034.jpg
#   inflating: animals/panda/panda_00035.jpg
#   inflating: animals/panda/panda_00036.jpg
#   inflating: animals/panda/panda_00037.jpg
#   inflating: animals/panda/panda_00038.jpg
#   inflating: animals/panda/panda_00039.jpg
#   inflating: animals/panda/panda_00040.jpg
#   inflating: animals/panda/panda_00041.jpg
#   inflating: animals/panda/panda_00042.jpg
#   inflating: animals/panda/panda_00043.jpg
#   inflating: animals/panda/panda_00044.jpg
#   inflating: animals/panda/panda_00045.jpg
#   inflating: animals/panda/panda_00046.jpg
#   inflating: animals/panda/panda_00047.jpg
#   inflating: animals/panda/panda_00048.jpg
#   inflating: animals/panda/panda_00049.jpg
#   inflating: animals/panda/panda_00050.jpg
#   inflating: animals/panda/panda_00051.jpg
#   inflating: animals/panda/panda_00052.jpg
#   inflating: animals/panda/panda_00053.jpg
#   inflating: animals/panda/panda_00054.jpg
#   inflating: animals/panda/panda_00055.jpg
#   inflating: animals/panda/panda_00056.jpg
#   inflating: animals/panda/panda_00057.jpg
#   inflating: animals/panda/panda_00058.jpg
#   inflating: animals/panda/panda_00059.jpg
#   inflating: animals/panda/panda_00060.jpg
#   inflating: animals/panda/panda_00061.jpg
#   inflating: animals/panda/panda_00062.jpg
#   inflating: animals/panda/panda_00063.jpg
#   inflating: animals/panda/panda_00064.jpg
#   inflating: animals/panda/panda_00065.jpg
#   inflating: animals/panda/panda_00066.jpg
#   inflating: animals/panda/panda_00067.jpg
#   inflating: animals/panda/panda_00068.jpg
#   inflating: animals/panda/panda_00069.jpg
#   inflating: animals/panda/panda_00070.jpg
#   inflating: animals/panda/panda_00071.jpg
#   inflating: animals/panda/panda_00072.jpg
#   inflating: animals/panda/panda_00073.jpg
#   inflating: animals/panda/panda_00074.jpg
#   inflating: animals/panda/panda_00075.jpg
#   inflating: animals/panda/panda_00076.jpg
#   inflating: animals/panda/panda_00077.jpg
#   inflating: animals/panda/panda_00078.jpg
#   inflating: animals/panda/panda_00079.jpg
#   inflating: animals/panda/panda_00080.jpg
#   inflating: animals/panda/panda_00081.jpg
#   inflating: animals/panda/panda_00082.jpg
#   inflating: animals/panda/panda_00083.jpg
#   inflating: animals/panda/panda_00084.jpg
#   inflating: animals/panda/panda_00085.jpg
#   inflating: animals/panda/panda_00086.jpg
#   inflating: animals/panda/panda_00087.jpg
#   inflating: animals/panda/panda_00088.jpg
#   inflating: animals/panda/panda_00089.jpg
#   inflating: animals/panda/panda_00090.jpg
#   inflating: animals/panda/panda_00091.jpg
#   inflating: animals/panda/panda_00092.jpg
#   inflating: animals/panda/panda_00093.jpg
#   inflating: animals/panda/panda_00094.jpg
#   inflating: animals/panda/panda_00095.jpg
#   inflating: animals/panda/panda_00096.jpg
#   inflating: animals/panda/panda_00097.jpg
#   inflating: animals/panda/panda_00098.jpg
#   inflating: animals/panda/panda_00099.jpg
#   inflating: animals/panda/panda_00100.jpg

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from collections import Counter

# %%
Dataset_dir = 'animals'
Categories = []
for c in os.listdir(Dataset_dir):
    Categories.append(c)
print(Categories)
# Out:
# ['dogs', 'panda', 'cats']

# %%
IMG_SIZE = 32
NUM_IMAGES = 300

all_data = []
for category in Categories:
    path = os.path.join(Dataset_dir, category)
    class_index = Categories.index(category)
    for img_name in os.listdir(path):
        img_path = os.path.join(path, img_name)
        all_data.append((img_path, class_index, img_name))

random.shuffle(all_data)
selected_data = all_data[:NUM_IMAGES]

# %%
features = []
labels = []
display_data = []

for img_path, class_index, img_name in selected_data:
    try:
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        features.append(img.flatten() / 255.0)
        labels.append(class_index)
        display_data.append((img, class_index, img_name))
    except:
        continue

features = np.array(features)
labels = np.array(labels)

# %%
plt.figure(figsize=(20, 20))
for i in range(min(len(display_data), 300)):
    img, _, name = display_data[i]
    plt.subplot(15, 20, i + 1)
    plt.imshow(img, cmap='gray')
    plt.title(name[:100], fontsize=6)
    plt.axis('off')

plt.suptitle("Selected All Grayscale Images with Filenames", fontsize=18)
plt.tight_layout()
plt.subplots_adjust(top=0.92)
plt.show()

print("Total images processed:", len(features))
# Out:
# Total images processed: 300

# %%
def manhattan_distance(vec1, vec2):

    return np.sum(np.abs(vec1 - vec2))


def euclidean_distance(vec1, vec2):

    return np.sqrt(np.sum((vec1 - vec2) ** 2))

# %%
data = list(zip(features, labels))
random.shuffle(data)
fold_size = len(data) // 5
folds = [data[i * fold_size : (i + 1) * fold_size] for i in range(5)]
remainder = len(data) % 5
for i in range(remainder):
    folds[i].append(data[5 * fold_size + i])


for i, fold in enumerate(folds):
    print(f"Fold {i+1} size:", len(fold))
# Out:
# Fold 1 size: 60
# Fold 2 size: 60
# Fold 3 size: 60
# Fold 4 size: 60
# Fold 5 size: 60

# %%
def knn_predict(X_train, y_train, x_test, k=7, distance_type='l2'):
    distances = []
    for i in range(len(X_train)):
        if distance_type == 'l1':
            dist = manhattan_distance(X_train[i], x_test)
        else:
            dist = euclidean_distance(X_train[i], x_test)
        distances.append((dist, y_train[i]))


    distances.sort(key=lambda x: x[0])

    k_labels = [label for _, label in distances[:k]]

    most_common = Counter(k_labels).most_common(1)
    return most_common[0][0]

# %%
def run_knn_cross_validation(folds, k_values, distance_type='l2'):
    fold_wise_accuracies = []

    for fold_index in range(5):

        validation_data = folds[fold_index]
        training_data = []
        for i in range(5):
            if i != fold_index:
                training_data.extend(folds[i])
        X_train = np.array([item[0] for item in training_data])
        y_train = np.array([item[1] for item in training_data])
        X_val = np.array([item[0] for item in validation_data])
        y_val = np.array([item[1] for item in validation_data])

        fold_accuracies = []

        for k in k_values:
            correct = 0
            for i in range(len(X_val)):
                pred = knn_predict(X_train, y_train, X_val[i], k=k, distance_type=distance_type)
                if pred == y_val[i]:
                    correct += 1
            accuracy = (correct / len(X_val)) * 100
            fold_accuracies.append(accuracy)

        fold_wise_accuracies.append(fold_accuracies)

    avg_accuracies = np.mean(fold_wise_accuracies, axis=0)
    return fold_wise_accuracies, avg_accuracies

# %%
def evaluate_knn(distance_func, label=""):
    k_best = 3
    y_true_all = []
    y_pred_all = []

    for fold_index in range(5):
        validation_set = folds[fold_index]
        training_set = [item for i, fold in enumerate(folds) if i != fold_index for item in fold]

        for val_img, val_label in validation_set:
            distances = [(distance_func(val_img, train_img), train_label)
                         for train_img, train_label in training_set]
            pred = knn_predict(distances, k_best)
            y_true_all.append(val_label)
            y_pred_all.append(pred)

    print(f"\nResults for {label}:")

# %%
K_values = np.arange(1, 21)


fold_acc_l1, avg_acc_l1 = run_knn_cross_validation(folds, K_values, distance_type='l1')
fold_acc_l2, avg_acc_l2 = run_knn_cross_validation(folds, K_values, distance_type='l2')


def plot_knn_accuracy(K, fold_accuracies, avg_accuracies, title, color):
    plt.figure(figsize=(10, 6))

    for i, acc in enumerate(fold_accuracies):
        plt.plot(K, acc, 'o', label=f'Fold {i+1}', alpha=0.6)

    plt.plot(K, avg_accuracies, 'o-', color=color, label='Average Accuracy', linewidth=1)

    plt.xlabel("K - Nearest Neighbors")
    plt.ylabel("Accuracy (%)")
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.xticks(np.arange(1, 21, 1))
    plt.ylim(20, 70)
    plt.tight_layout()
    plt.show()

plot_knn_accuracy(K_values, fold_acc_l1, avg_acc_l1, "KNN Accuracy with Manhattan (L1) Distance", color='red')
plot_knn_accuracy(K_values, fold_acc_l2, avg_acc_l2, "KNN Accuracy with Euclidean (L2) Distance", color='green')

# %%
print("Average Accuracy for Manhattan (L1) Distance:")
for i in range(len(K_values)):
    print(f"K = {K_values[i]:2d} : {avg_acc_l1[i]:.2f}%")

print("\nAverage Accuracy for Euclidean (L2) Distance:")
for i in range(len(K_values)):
    print(f"K = {K_values[i]:2d} : {avg_acc_l2[i]:.2f}%")
# Out:
# Average Accuracy for Manhattan (L1) Distance:
# K =  1 : 35.33%
# K =  2 : 35.33%
# K =  3 : 38.67%
# K =  4 : 33.00%
# K =  5 : 37.33%
# K =  6 : 34.67%
# K =  7 : 39.00%
# K =  8 : 37.67%
# K =  9 : 40.67%
# K = 10 : 39.33%
# K = 11 : 42.33%
# K = 12 : 41.33%
# K = 13 : 41.67%
# K = 14 : 41.67%
# K = 15 : 39.67%
# K = 16 : 40.33%
# K = 17 : 41.00%
# K = 18 : 42.00%
# K = 19 : 42.67%
# K = 20 : 43.00%
#
# Average Accuracy for Euclidean (L2) Distance:
# K =  1 : 32.33%
# K =  2 : 32.33%
# K =  3 : 34.33%
# K =  4 : 32.67%
# K =  5 : 33.67%
# K =  6 : 33.33%
# K =  7 : 37.00%
# K =  8 : 35.67%
# K =  9 : 36.67%
# K = 10 : 33.33%
# K = 11 : 38.00%
# K = 12 : 36.00%
# K = 13 : 35.33%
# K = 14 : 35.00%
# K = 15 : 35.33%
# K = 16 : 37.33%
# K = 17 : 39.00%
# K = 18 : 38.67%
# K = 19 : 39.33%
# K = 20 : 38.33%
